# %%
import pandas as pd
import numpy as np
import h5py

def process_datasets(numbers):
    with h5py.File('/gpfs/slac/atlas/fs1/d/hjia625/Smart_Pixel/data.hdf5', 'w') as h5f:
        for charge_type in ['positive-charge', 'negative-charge']:
            sig_input_list = []
            sig_target_list = []
            bkg_input_list = []
            bkg_target_list = []

            for number in numbers:
                print("Processing ", charge_type, number)
                
                # Read the target data
                target_file = f'/gpfs/slac/atlas/fs1/d/hjia625/Smart_Pixel/{charge_type}/labels_d{number}.csv'
                target_df = pd.read_csv(target_file)

                # Read the input data
                input_file = f'/gpfs/slac/atlas/fs1/d/hjia625/Smart_Pixel/{charge_type}/recon8t_d{number}.csv'
                input_df = pd.read_csv(input_file)

                # Filter for significant and background data
                sig_indices = target_df['pt'].abs() >= 2
                bkg_indices = ~sig_indices

                # Reshape and append the significant input data
                sig_input_reshaped = input_df[sig_indices].to_numpy().reshape(-1, 8*13*21).astype(np.float16)
                sig_input_list.append(sig_input_reshaped)

                # Reshape and append the significant target data
                sig_target_reshaped = target_df[sig_indices].to_numpy().reshape(-1, 13).astype(np.float16)
                sig_target_list.append(sig_target_reshaped)

                # Reshape background data
                bkg_input_reshaped = input_df[bkg_indices].to_numpy().reshape(-1, 8*13*21).astype(np.float16)
                bkg_target_reshaped = target_df[bkg_indices].to_numpy().reshape(-1, 13).astype(np.float16)

                # Random undersampling of the background data
                num_sig_samples = sig_input_reshaped.shape[0]
                random_indices = np.random.choice(bkg_input_reshaped.shape[0], num_sig_samples, replace=False)
                bkg_input_undersampled = bkg_input_reshaped[random_indices]
                bkg_target_undersampled = bkg_target_reshaped[random_indices]

                bkg_input_list.append(bkg_input_undersampled)
                bkg_target_list.append(bkg_target_undersampled)

            # Convert lists to NumPy arrays
            sig_input_combined = np.vstack(sig_input_list)
            sig_target_combined = np.vstack(sig_target_list)
            bkg_input_combined = np.vstack(bkg_input_list)
            bkg_target_combined = np.vstack(bkg_target_list)

            # Save data in HDF5 format
            h5f.create_dataset(f'{charge_type}_sig_input', data=sig_input_combined)
            h5f.create_dataset(f'{charge_type}_sig_target', data=sig_target_combined)
            h5f.create_dataset(f'{charge_type}_bkg_input', data=bkg_input_combined)
            h5f.create_dataset(f'{charge_type}_bkg_target', data=bkg_target_combined)

number_list = list(range(16501,16651))
process_datasets(number_list)  # Replace with actual numbers
# Out:
# Processing  positive-charge 16501
# Processing  positive-charge 16502
# Processing  positive-charge 16503
# Processing  positive-charge 16504
# Processing  positive-charge 16505
# Processing  positive-charge 16506
# Processing  positive-charge 16507
# Processing  positive-charge 16508
# Processing  positive-charge 16509
# Processing  positive-charge 16510
# Processing  positive-charge 16511
# Processing  positive-charge 16609
# Processing  positive-charge 16610
# Processing  positive-charge 16611
# Processing  positive-charge 16612
# Processing  positive-charge 16613
# Processing  positive-charge 16614
# Processing  positive-charge 16615
# Processing  positive-charge 16616
# Processing  positive-charge 16617
# Processing  positive-charge 16618
# Processing  positive-charge 16619
# Processing  positive-charge 16620
# Processing  positive-charge 16621
# Processing  positive-charge 16622
# Processing  positive-charge 16623
# Processing  positive-charge 16624
# Processing  positive-charge 16625
# Processing  positive-charge 16626
# Processing  positive-charge 16627
# Processing  positive-charge 16628
# Processing  positive-charge 16629
# Processing  positive-charge 16630
# Processing  positive-charge 16631
# Processing  positive-charge 16632
# Processing  positive-charge 16633
# Processing  positive-charge 16634
# Processing  positive-charge 16635
# Processing  positive-charge 16636
# Processing  positive-charge 16637
# Processing  positive-charge 16638
# Processing  positive-charge 16639
# Processing  positive-charge 16640
# Processing  positive-charge 16641
# Processing  positive-charge 16642
# Processing  positive-charge 16643
# Processing  positive-charge 16644
# Processing  positive-charge 16645
# Processing  positive-charge 16646
# Processing  positive-charge 16647
# Processing  positive-charge 16648
# Processing  positive-charge 16649
# Processing  positive-charge 16650
# Processing  negative-charge 16501
# Processing  negative-charge 16502
# Processing  negative-charge 16503
# Processing  negative-charge 16504
# Processing  negative-charge 16505
# Processing  negative-charge 16506
# Processing  negative-charge 16507
# Processing  negative-charge 16508
# Processing  negative-charge 16509
# Processing  negative-charge 16510
# Processing  negative-charge 16511
# Processing  negative-charge 16512
# Processing  negative-charge 16513
# Processing  negative-charge 16514
# Processing  negative-charge 16515
# Processing  negative-charge 16516
# Processing  negative-charge 16517
# Processing  negative-charge 16518
# Processing  negative-charge 16519
# Processing  negative-charge 16520
# Processing  negative-charge 16521
# Processing  negative-charge 16522
# Processing  negative-charge 16523
# Processing  negative-charge 16524
# Processing  negative-charge 16525
# Processing  negative-charge 16526
# Processing  negative-charge 16527
# Processing  negative-charge 16528
# Processing  negative-charge 16529
# Processing  negative-charge 16530
# Processing  negative-charge 16531
# Processing  negative-charge 16532
# Processing  negative-charge 16533
# Processing  negative-charge 16534
# Processing  negative-charge 16535
# Processing  negative-charge 16536
# Processing  negative-charge 16537
# Processing  negative-charge 16538
# Processing  negative-charge 16539
# Processing  negative-charge 16540
# Processing  negative-charge 16541
# Processing  negative-charge 16542
# Processing  negative-charge 16543
# Processing  negative-charge 16544
# Processing  negative-charge 16545
# Processing  negative-charge 16546
# Processing  negative-charge 16547
# Processing  negative-charge 16548
# Processing  negative-charge 16549
# Processing  negative-charge 16550
# Processing  negative-charge 16551
# Processing  negative-charge 16552
# Processing  negative-charge 16553
# Processing  negative-charge 16554
# Processing  negative-charge 16555
# Processing  negative-charge 16556
# Processing  negative-charge 16557
# Processing  negative-charge 16558
# Processing  negative-charge 16559
# Processing  negative-charge 16560
# Processing  negative-charge 16561
# Processing  negative-charge 16562
# Processing  negative-charge 16563
# Processing  negative-charge 16564
# Processing  negative-charge 16565
# Processing  negative-charge 16566
# Processing  negative-charge 16567
# Processing  negative-charge 16568
# Processing  negative-charge 16569
# Processing  negative-charge 16570
# Processing  negative-charge 16571
# Processing  negative-charge 16572
# Processing  negative-charge 16573
# Processing  negative-charge 16574
# Processing  negative-charge 16575
# Processing  negative-charge 16576
# Processing  negative-charge 16577
# Processing  negative-charge 16578
# Processing  negative-charge 16579
# Processing  negative-charge 16580
# Processing  negative-charge 16581
# Processing  negative-charge 16582
# Processing  negative-charge 16583
# Processing  negative-charge 16584
# Processing  negative-charge 16585
# Processing  negative-charge 16586
# Processing  negative-charge 16587
# Processing  negative-charge 16588
# Processing  negative-charge 16589
# Processing  negative-charge 16590
# Processing  negative-charge 16591
# Processing  negative-charge 16592
# Processing  negative-charge 16593
# Processing  negative-charge 16594
# Processing  negative-charge 16595
# Processing  negative-charge 16596
# Processing  negative-charge 16597
# Processing  negative-charge 16598
# Processing  negative-charge 16599
# Processing  negative-charge 16600
# Processing  negative-charge 16601
# Processing  negative-charge 16602
# Processing  negative-charge 16603
# Processing  negative-charge 16604
# Processing  negative-charge 16605
# Processing  negative-charge 16606
# Processing  negative-charge 16607
# Processing  negative-charge 16608
# Processing  negative-charge 16609
# Processing  negative-charge 16610
# Processing  negative-charge 16611
# Processing  negative-charge 16612
# Processing  negative-charge 16613
# Processing  negative-charge 16614
# Processing  negative-charge 16615
# Processing  negative-charge 16616
# Processing  negative-charge 16617
# Processing  negative-charge 16618
# Processing  negative-charge 16619
# Processing  negative-charge 16620
# Processing  negative-charge 16621
# Processing  negative-charge 16622
# Processing  negative-charge 16623
# Processing  negative-charge 16624
# Processing  negative-charge 16625
# Processing  negative-charge 16626
# Processing  negative-charge 16627
# Processing  negative-charge 16628
# Processing  negative-charge 16629
# Processing  negative-charge 16630
# Processing  negative-charge 16631
# Processing  negative-charge 16632
# Processing  negative-charge 16633
# Processing  negative-charge 16634
# Processing  negative-charge 16635
# Processing  negative-charge 16636
# Processing  negative-charge 16637
# Processing  negative-charge 16638
# Processing  negative-charge 16639
# Processing  negative-charge 16640
# Processing  negative-charge 16641
# Processing  negative-charge 16642
# Processing  negative-charge 16643
# Processing  negative-charge 16644
# Processing  negative-charge 16645
# Processing  negative-charge 16646
# Processing  negative-charge 16647
# Processing  negative-charge 16648
# Processing  negative-charge 16649
# Processing  negative-charge 16650
